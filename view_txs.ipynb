# %%
import pandas as pd

# Chargement du fichier CSV dans un DataFrame
df = pd.read_csv('/home/block67/Bureau/Txs_afrikmoney/transactionmarchand_duplicate.csv')

display(df)
# Out:
#         idtransaction  IDtransfert  mode  montant  \
# 0                   1   6024417554     3        1
# 1                   2   6024469422     3        1
# 2                   3   6029777365     3        1
# 3                   4   6033694636     3        1
# 4                   5   6035999882     3        1
# ...               ...          ...   ...      ...
# 499995         499996   6024417554     3        1
# 499996         499997   6024469422     3        1
# 499997         499998   6029777365     3        1
# 499998         499999   6033694636     3        1
# 499999         500000   6035999882     3        1
#
#                       nomdestinataire    numero  operateur datetransaction  \
# 0       ABDOUL-RAHAMANE BODA SALISSOU  67030967  MTN MONEY      27/11/2023
# 1            YELOGNISSE DANIEL GBEOU-  97724561  MTN MONEY      27/11/2023
# 2       ABDOUL-RAHAMANE BODA SALISSOU  67030967  MTN MONEY      28/11/2023
# ...
